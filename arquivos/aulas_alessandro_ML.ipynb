# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
iris_treino = pd.read_csv('/content/sample_data/baseDados/iris-treino.csv')
iris_teste = pd.read_csv('/content/sample_data/baseDados/iris-teste.csv')

# %%
iris_treino.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           6.2          3.4           5.4          2.3   virginica
# 1           5.1          3.3           1.7          0.5      setosa
# 2           6.7          2.5           5.8          1.8   virginica
# 3           5.6          2.5           3.9          1.1  versicolor
# 4           4.4          3.2           1.3          0.2      setosa

# %%
iris_teste.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           7.7          3.8           6.7          2.2   virginica
# 1           6.3          3.3           6.0          2.5   virginica
# 2           7.2          3.2           6.0          1.8   virginica
# 3           7.0          3.2           4.7          1.4  versicolor
# 4           6.8          2.8           4.8          1.4  versicolor

# %%
iris_treino.iloc[-1]
# Out:
# sepal_length           6.2
# sepal_width            2.2
# petal_length           4.5
# petal_width            1.5
# species         versicolor
# Name: 63, dtype: object

# %%
lista = [1,2,3,5,8,13,21,34,55]

# %%
lista[2:6]
# Out:
# [3, 5, 8, 13]

# %%
lista[:4]
# Out:
# [1, 2, 3, 5]

# %%
lista[6:-1]
# Out:
# [21, 34]

# %%
lista[:]
# Out:
# [1, 2, 3, 5, 8, 13, 21, 34, 55]

# %%
iris_treino.iloc[:,-1]
# Out:
# 0      virginica
# 1         setosa
# 2      virginica
# 3     versicolor
# 4         setosa
#          ...
# 59        setosa
# 60    versicolor
# 61    versicolor
# 62    versicolor
# 63    versicolor
# Name: species, Length: 64, dtype: object

# %%
iris_treino.iloc[: , : -1]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            6.2          3.4           5.4          2.3
# 1            5.1          3.3           1.7          0.5
# 2            6.7          2.5           5.8          1.8
# 3            5.6          2.5           3.9          1.1
# 4            4.4          3.2           1.3          0.2
# ..           ...          ...           ...          ...
# 59           4.7          3.2           1.3          0.2
# 60           6.6          2.9           4.6          1.3
# 61           6.4          3.2           4.5          1.5
# 62           6.4          2.9           4.3          1.3
# 63           6.2          2.2           4.5          1.5
#
# [64 rows x 4 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x = iris_treino.iloc[: , -1].unique()
x.sort()
x
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X_train = iris_treino.iloc[: , : -1].values
X_test = iris_teste.iloc[: , : -1].values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# classes para modelo
#fit / predict

#classes para pré-processamento
#fit / transform

# teste
#
#  amostra     treino -> 66% ---> indireta
#              teste -> 35% ----> f(x)

# %%
le = LabelEncoder().fit(iris_treino['species'])

# %%
y_train = le.transform(iris_treino['species'])
y_test = le.transform(iris_teste['species'])

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train);
plt.figure(figsize=(5,6));
sklearn.tree.plot_tree(clf, feature_names=iris_treino.columns[:-1]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 clf = DecisionTreeClassifier(random_state=42)
#       2 clf.fit(X_train, y_train);
#       3 plt.figure(figsize=(5,6))
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
ypred = clf.predict(X_test)

# %%
ypred = clf.predict(X_test)
display(ypred)
# Out:
# array([2, 2, 2, 1, 1, 2, 2, 1, 0, 1, 2, 1, 0, 0, 2, 1, 1, 0, 1, 0, 2, 2,
#        2, 0, 0, 2, 2, 1, 2, 2, 1, 1, 2, 1, 0, 0, 1, 1, 2, 1, 2, 2, 1, 0,
#        2, 0, 1, 2, 2, 0, 0, 1, 0, 0, 1, 1, 1, 2, 0, 2, 0, 0, 1, 1, 0, 0,
#        0, 2, 2, 0, 1, 0, 1, 0, 0, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2])

# %%
le.inverse_transform(ypred)
# Out:
# array(['virginica', 'virginica', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'virginica', 'versicolor', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'setosa', 'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'virginica', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'virginica', 'setosa',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'versicolor',
#        'versicolor', 'versicolor', 'virginica', 'setosa', 'virginica',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
# ...

# %%
tabela = pd.DataFrame(columns=['Classe verdadeira', 'Classe predita'])
tabela.iloc[:,0] = iris_teste['species']
tabela.iloc[:,1] = le.inverse_transform(ypred)
tabela
# Out:
#    Classe verdadeira Classe predita
# 0          virginica      virginica
# 1          virginica      virginica
# 2          virginica      virginica
# 3         versicolor     versicolor
# 4         versicolor     versicolor
# ..               ...            ...
# 81        versicolor     versicolor
# 82         virginica     versicolor
# 83         virginica      virginica
# 84         virginica      virginica
# 85         virginica      virginica
#
# [86 rows x 2 columns]

# %%
tabela.iloc[:,0] != tabela.iloc[:,1]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81    False
# 82     True
# 83    False
# 84    False
# 85    False
# Length: 86, dtype: bool

# %%
len(tabela[tabela.iloc[:,0] == tabela.iloc[:,1]]) / len(y_test)
# Out:
# 0.9534883720930233

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9534883720930233

# %%
## Testando para saber se a acurácia resultará no mesmo valor

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9534883720930233

# %%
import seaborn as sns

# %%
sns.pairplot(iris_treino, hue='species')

# %%
clf_profundidade_2 = DecisionTreeClassifier(max_depth=2)
clf_profundidade_2.fit(X_train, y_train);

# %%
plt.figure(figsize=(5,6));
sklearn.tree.plot_tree(clf_profundidade_2, feature_names=iris_treino.columns[:-1], class_names=le.classes_);

# %%
ypred = clf_profundidade_2.predict(X_test)
accuracy_score(y_test, ypred)
# Out:
# 0.9418604651162791

# %%
## parâmetro -> variável do modelo que o indutor ajusta aos dados
## hiperparâmentros -> variáveis do indutor que afetam os parâmetros indiretamente

# %%
## Modelo KNN
## modelo de exemplos dos vizinhos mais próximos
## não possui classe de treinamento -> cria uma cópia (protótipo) exemplos de treinamentos
## k = procurar a vizinhança mais próxima, que pode ser 1, 3, etc..
## observação quando a vizinhança for K = 2, pode ocorrer de conflitos
## função de distância:
## formas diferentes de calcular a distância
## afetam a complexidade do KNN -->  ou a fronteira da separação

# %% [markdown]
# Separando conjuntos de treino, teste e validação
#
# - treino: para encontrar os parâmetros/treinar o modelo
# - teste: para prever o desempenho do modelo
# - validação: para testar e ajudar hiperparâmetro
#
# - qual o melhor modelo:
# Knn: para verificar o desempenho do knn, no treino, conforme o melhor: k=1, k=3, k=5, k=10 e depois realizar a validação.
# árvore de decisão: realizar o mesmo treino de desempenho na árvore de decisão
#
# - sklearn_model_selection import train_test_split: utilização do método para particionamento, separar em vários subconjuntos, que podem ser utilizados para treino e teste, mantendo os elementos originais, geralmente 70% para treino e 30%, teste.
#
# -- conjunto de treino e validação
# - original -> 150
# treino->+validação = 105
# teste->45
#
# 2ª divisão
# treino->84
# validação->21

# %% [markdown]
# -- treinar e validar o k-nn com diferentes valores de k
# k = 1
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.sklearn import accuracy
#
# h1 = KneighborsClassifier(n_neighbors=1)
#
# h1.fit(Xtreino, ytreino);
#
# ypred = h1.precdict(Xval)
# accuracy_score(yval, ypred)
#
# for k in range(1, 11):
#   h = KneighborsClassifier(n_neighbors=k)
#   h.fit(Xtreino, ytreino);
#   ypred = h
#
#   print(f'k = (k), acc = (100*accuracy_score(yval, ypred):. 2f)%')

# %% [markdown]
# teste final com todos os dados de treino e validação
#
# Xtreino = Xtreino_e_validacao
# ytreino = ytreino_e_validacao
